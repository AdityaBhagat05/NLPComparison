# %%
import pickle
def load_pickle_file(path):
    with open(path,"rb") as file:
        data=pickle.load(file)
    return data

# %%
train_data = load_pickle_file("train_pos_data.pkl")
test_data = load_pickle_file("test_pos_data.pkl")

# %%
test_sentences = [" ".join([word for word, tag in sent]) for sent in test_data]
true_tags = [[tag for word, tag in sent] for sent in test_data]

# %%
print(test_sentences[:5])
# Out:
# ['The average of interbank offered rates for dollar deposits in the Chandrapur market based * on quotations at five major banks .', 'The company plugged itself right into satbir campaign rhetoric about * rebuilding the South Bronx and kept *-1 using the minority -- South Bronx angle through the Reagan ritik .', "nirosha Madison , a corporate trader with ARIES BIOTECH PRIVATE in Azamgarh , traced the dollar 's recent solid performance against the yen to purchases of securities by Japanese insurance companies and trust banks and the sense that another wave of investment is waiting in the wings .", 'Not that Anand and Bidar disagree on the Japanese acquisitions ; indeed , each has come out in favor of unfettered investment in the Palanpur .', "*-1 No dummies , the drivers pointed out 0 they still had space on their machines for another sponsor 's name or two ."]

# %%
print(true_tags[:5])
# Out:
# [['DT', 'NN', 'IN', 'NN', 'VBD', 'NNS', 'IN', 'NN', 'NNS', 'IN', 'DT', 'NNP', 'NN', 'VBN', '-NONE-', 'IN', 'NNS', 'IN', 'CD', 'JJ', 'NNS', '.'], ['DT', 'NN', 'VBD', 'PRP', 'RB', 'IN', 'NNP', 'NN', 'NN', 'IN', '-NONE-', 'VBG', 'DT', 'NNP', 'NNP', 'CC', 'VBD', '-NONE-', 'VBG', 'DT', 'NN', ':', 'NNP', 'NNP', 'NN', 'IN', 'DT', 'NNP', 'CD', '.'], ['NNP', 'NNP', ',', 'DT', 'JJ', 'NN', 'IN', 'NNP', 'IN', 'NNP', 'IN', 'NNP', ',', 'VBD', 'DT', 'NN', 'POS', 'JJ', 'JJ', 'NN', 'IN', 'DT', 'NN', 'TO', 'NNS', 'IN', 'NNS', 'IN', 'JJ', 'NN', 'NNS', 'CC', 'NN', 'NNS', 'CC', 'DT', 'NN', 'IN', 'DT', 'NN', 'IN', 'NN', 'VBZ', 'VBG', 'IN', 'DT', 'NNS', '.'], ['RB', 'IN', 'NNP', 'CC', 'NNP', 'VBP', 'IN', 'DT', 'JJ', 'NNS', ':', 'RB', ',', 'DT', 'VBZ', 'VBN', 'RP', 'IN', 'NN', 'IN', 'JJ', 'NN', 'IN', 'DT', 'NNP', '.'], ['-NONE-', 'DT', 'NNS', ',', 'DT', 'NNS', 'VBD', 'RP', '-NONE-', 'PRP', 'RB', 'VBD', 'NN', 'IN', 'PRP$', 'NNS', 'IN', 'DT', 'NN', 'POS', 'NN', 'CC', 'CD', '.']]

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import SystemMessage, HumanMessage
import time
import os
from dotenv import load_dotenv
import re
load_dotenv()
# Out:
# True

# %%
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite", temperature=0)

# %%
PENN_TAGS = (
    "CC, CD, DT, EX, FW, IN, JJ, JJR, JJS, LS, MD, NN, NNS, NNP, NNPS, "
    "PDT, POS, PRP, PRP$, RB, RBR, RBS, RP, SYM, TO, UH, "
    "VB, VBD, VBG, VBN, VBP, VBZ, WDT, WP, WP$, WRB, ., ,, :, `` , '' , -NONE-"
)

EXAMPLES = [
    ("The cat sat on the mat.", "DT NN VBD IN DT NN ."),
    ("He runs quickly.", "PRP VBZ RB ."),
    ("Dogs bark loudly at strangers.", "NNS VBP RB IN NNS ."),
]

EXAMPLES_TEXT = "\n".join(
    f"Sentence: {s}\nTags: {t}\n" for s, t in EXAMPLES
)

# %%
def build_prompt(batch_sentences):
    system_msg = SystemMessage(
        content=(
            "You are a strict and deterministic POS tagger.\n"
            "Use ONLY the Penn Treebank POS tagset. Each tag sequence must exactly match token order.\n"
            "Return only space-separated tag lines, one per sentence, with no explanations or extra text."
        )
    )

    human_prompt = (
        f"PENN TAGS:\n{PENN_TAGS}\n\n"
        f"Few-shot examples:\n{EXAMPLES_TEXT}\n\n"
        "Now tag these sentences strictly in the same format.\n\n"
        "INPUT SENTENCES:\n" + "\n".join(batch_sentences)
    )

    human_msg = HumanMessage(content=human_prompt)
    return [system_msg, human_msg]

# %%
def parse_response(response_text, expected_n):
    tagset = {t.strip() for t in PENN_TAGS.split(",")}
    lines = [l.strip() for l in response_text.strip().splitlines() if l.strip()]
    parsed = []
    for line in lines:
        tokens = [tok for tok in line.split() if tok in tagset]
        parsed.append(tokens)
    # Adjust length if mismatch
    if len(parsed) != expected_n:
        parsed = parsed[:expected_n] + [[] for _ in range(expected_n - len(parsed))]
    return parsed

# %%
def call_model(prompt_messages):
    response = model.invoke(prompt_messages)
    return response.content.strip()

# %%
def compute_accuracy(pred_tags, true_tags):
    correct, total = 0, 0
    for pred, true in zip(pred_tags, true_tags):
        for p, t in zip(pred, true):
            total += 1
            if p == t:
                correct += 1
    return round((correct / total) * 100, 2) if total > 0 else 0

# %%
predicted_tags = []
batch_size = 20

# %%
from tqdm import tqdm

# %%
for i in tqdm(range(0, len(test_sentences), batch_size), desc="Processing batches"):
    batch = test_sentences[i:i + batch_size]
    prompt_messages = build_prompt(batch)
    response_text = call_model(prompt_messages)
    parsed = parse_response(response_text, len(batch))
    predicted_tags.extend(parsed)
# Out:
# Processing batches: 100%|██████████| 40/40 [1:21:27<00:00, 122.19s/it]

# %%
accuracy = compute_accuracy(predicted_tags, true_tags)

# %%
print(accuracy)
# Out:
# 20.71

# %%
for i, (sent, pred, true) in enumerate(zip(test_sentences, predicted_tags, true_tags)):
    if i >= 10:
        break
    print(f"{i+1}. Sentence: {sent}")
    print(f"Predicted: {' '.join(pred)}")
    print(f"True:      {' '.join(true)}\n")
# Out:
# 1. Sentence: The average of interbank offered rates for dollar deposits in the Chandrapur market based * on quotations at five major banks .
# Predicted: DT JJ IN NNS IN NN IN DT NNP NNS .
# True:      DT NN IN NN VBD NNS IN NN NNS IN DT NNP NN VBN -NONE- IN NNS IN CD JJ NNS .
#
# 2. Sentence: The company plugged itself right into satbir campaign rhetoric about * rebuilding the South Bronx and kept *-1 using the minority -- South Bronx angle through the Reagan ritik .
# Predicted: DT NN VBD PRP RB IN NNP NNS IN VBZ DT NN .
# True:      DT NN VBD PRP RB IN NNP NN NN IN -NONE- VBG DT NNP NNP CC VBD -NONE- VBG DT NN : NNP NNP NN IN DT NNP CD .
#
# 3. Sentence: nirosha Madison , a corporate trader with ARIES BIOTECH PRIVATE in Azamgarh , traced the dollar 's recent solid performance against the yen to purchases of securities by Japanese insurance companies and trust banks and the sense that another wave of investment is waiting in the wings .
# Predicted: NNP NNP DT NN NN IN NNP NNP IN NNP VBD DT NN NNS NNS IN NNS NNS .
# True:      NNP NNP , DT JJ NN IN NNP IN NNP IN NNP , VBD DT NN POS JJ JJ NN IN DT NN TO NNS IN NNS IN JJ NN NNS CC NN NNS CC DT NN IN DT NN IN NN VBZ VBG IN DT NNS .
#
# 4. Sentence: Not that Anand and Bidar disagree on the Japanese acquisitions ; indeed , each has come out in favor of unfettered investment in the Palanpur .
# Predicted: RB WDT NNP CC NNP VBP IN DT NNP NNS RB PRP VBD RB IN JJ NN IN DT NNP .
# True:      RB IN NNP CC NNP VBP IN DT JJ NNS : RB , DT VBZ VBN RP IN NN IN JJ NN IN DT NNP .
#
# 5. Sentence: *-1 No dummies , the drivers pointed out 0 they still had space on their machines for another sponsor 's name or two .
# Predicted: DT NNS DT VBD PRP RB CD PRP$ NN IN CD CD CD CD .
# True:      -NONE- DT NNS , DT NNS VBD RP -NONE- PRP RB VBD NN IN PRP$ NNS IN DT NN POS NN CC CD .
#
# 6. Sentence: The defense lawyers ' group formed a task force *ICH*-1 *ICH*-3 this week , chaired * by New York Noida Lefcourt nikky 0 *T*-2 to deal with the matter .
# Predicted: DT NN NNS POS NN DT IN NNP NNP NNP TO VB DT NN .
# True:      DT NN NNS POS NN VBD DT NN NN -NONE- -NONE- DT NN , VBN -NONE- IN NNP NNP NN NNP , -NONE- -NONE- TO VB IN DT NN .
#
# 7. Sentence: It rose largely throughout the session after *-1 posting an intraday low of 2141.7 in the first 40 minutes of trading .
# Predicted: PRP VBD RB RB DT NN IN CD IN DT CD CD IN NN .
# True:      PRP VBD RB IN DT NN IN -NONE- VBG DT NN JJ IN CD IN DT JJ CD NNS IN NN .
#
# 8. Sentence: There may be others doing what she did *T*-1 . ''
# Predicted: WP MD NNS VBG PRP VBD . ''
# True:      EX MD VB NNS VBG WP PRP VBD -NONE- . ''
#
# 9. Sentence: The 1987 statute 0 Mrs. lav violated *T*-1 was designed *-2 *-3 to enforce provisions of South Carolina 's Puri
# Predicted: DT CD NN NN PRP VBD VBD TO VB NNS IN NNP NNP NNP
# True:      DT CD NN -NONE- NNP NNP VBD -NONE- VBD VBN -NONE- -NONE- TO VB NNS IN NNP NNP POS JJ
#
# 10. Sentence: The action followed by one day an ECOPHOS announcement that it will retain an investment banker * to explore alternatives `` 0 *T*-1 to maximize shareholder value , '' including the possible sale of the company .
# Predicted: DT NN VBD DT CD NN NN PRP VBD DT NN VBZ DT NN VBZ DT NN VBZ DT NN .
# True:      DT NN VBN IN CD NN DT NNP NN IN PRP MD VB DT NN NN -NONE- TO VB NNS `` -NONE- -NONE- TO VB NN NN , '' VBG DT JJ NN IN DT NN .

# %%
results = {
    "sentences": test_sentences,
    "predicted_tags": predicted_tags,
    "true_tags": true_tags,
    "accuracy": accuracy
}

with open("predicted_tags.pkl", "wb") as f:
    pickle.dump(results, f)

print("Predicted tags saved to predicted_tags.pkl")
# Out:
# Predicted tags saved to predicted_tags.pkl

# %%
import random

sample_indices = random.sample(range(len(test_sentences)), min(10, len(test_sentences)))

for idx in sample_indices:
    sent = test_sentences[idx]
    pred = predicted_tags[idx]
    true = true_tags[idx]
    print(f"Sentence {idx+1}: {sent}")
    print(f"Predicted: {' '.join(pred)}")
    print(f"True:      {' '.join(true)}")
    print(f"Predicted tag count: {len(pred)}, True tag count: {len(true)}\n")
# Out:
# Sentence 29: rajkaranta R. Breakey shittal Pamela J. Fischer RASAYANI (GUJARAT) PVT LTD
# Predicted: CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD CD ...
# True:      NNP NNP NNP NNP NNP NNP NNP NNP NNP IN NNP
# Predicted tag count: 4132, True tag count: 11
#
# Sentence 648: When it 's time for their biannual powwow *T*-1 , the nation 's manufacturing titans typically jet off to the sunny confines of resort towns like Boca Alandur Hot Karnal
# Predicted:
# True:      WRB PRP VBZ NN IN PRP$ JJ NN -NONE- , DT NN POS VBG NNS RB VBP RP TO DT JJ NNS IN NN NNS IN NNP NNP NNP NNP
# Predicted tag count: 0, True tag count: 30
#
# Sentence 217: Mr. preeti said 0 he will stay until Dec. 31 and work with his successor , who *T*-36 is *-1 to be named *-43 soon .
# Predicted:
# True:      NNP NNP VBD -NONE- PRP MD VB IN NNP CD CC VB IN PRP$ NN , WP -NONE- VBZ -NONE- TO VB VBN -NONE- RB .
# Predicted tag count: 0, True tag count: 26
#
# Sentence 125: shakutal Arafat has written to the chairman of VAPI ORGANIC CHEMICALS PRIVATE LIMITED asking him *-3 to back a Palestinian bid * to join the committee , the Palestine KEVIN ORGANICS PRIVATE LIMITED WAFA said VAKSHAL *T*-1 .
# Predicted: NNP NNP VBD TO DT NNP IN NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP NNP  ...
# True:      NNP NNP VBZ VBN TO DT NN IN DT NNP NNP NNP -NONE- VBG PRP -NONE- TO VB DT JJ NN -NONE- TO VB DT NN , DT NNP NNP NNP NN NN NNP VBD -NONE- -NONE- .
# Predicted tag count: 32722, True tag count: 38
#
# Sentence 570: SSN PHARMACEUTICALS PRIVATE , a once high-flying toy maker whose stock *T*-2 peaked at $ 65 *U* a share in the early 1980s , filed a Chapter 11 reorganization plan that *T*-1 provides just 1.125 cents a share for common stockholders .
# Predicted:
# True:      NNP NNPS NNP , DT RB JJ NN NN WP$ NN -NONE- JJ IN $ CD -NONE- DT NN IN DT JJ CD , VBD DT NN CD NN NN WDT -NONE- VBZ RB CD NNS DT NN IN JJ NNS .
# Predicted tag count: 0, True tag count: 42
#
# Sentence 20: -LRB- Few , if any , index-fund managers will risk *-1 leveraging performance by *-1 owning more than 100 % exposure to stocks , and equally few will want *-2 to own less than a 100 % position should stocks rise . -RRB-
# Predicted:
# True:      -LRB- JJ , IN DT , JJ NNS MD VB -NONE- VBG NN IN -NONE- VBG JJR IN CD NN NN TO NNS , CC RB JJ MD VB -NONE- TO VB JJR IN DT CD NN NN MD NNS VB . -RRB-
# Predicted tag count: 0, True tag count: 43
#
# Sentence 274: `` Each day that Congress SHREE *-1 to act *T*-2 ... will cause additional disruption in our borrowing schedule , * possibly resulting in higher interest costs to the taxpayer , '' Treasury Secretary Nicholas NEXTSHINE said anjara in a speech prepared * for delivery last night to a group of bankers .
# Predicted:
# True:      `` DT NN IN NNP VBZ -NONE- TO VB -NONE- : MD VB JJ NN IN PRP$ NN NN , -NONE- RB VBG IN JJR NN NNS TO DT NN , '' NNP NNP NNP NNP VBD -NONE- IN DT NN VBN -NONE- IN NN JJ NN TO DT NN IN NNS .
# Predicted tag count: 0, True tag count: 53
#
# Sentence 138: Brisk domestic demand due to increasing capital investment pushed up sales sharply in construction and industrial machinery divisions .
# Predicted:
# True:      JJ JJ NN JJ TO VBG NN NN VBD RP NNS RB IN NN CC JJ NN NNS .
# Predicted tag count: 0, True tag count: 19
#
# Sentence 255: In addition to the damages , the suit seeks a court order preventing the guild from *-2 punishing *RNR*-1 or retaliating against *RNR*-1 Mr. Trudeau .
# Predicted:
# True:      IN NN TO DT NNS , DT NN VBZ DT NN NN VBG DT NN IN -NONE- VBG -NONE- CC VBG IN -NONE- NNP NNP .
# Predicted tag count: 0, True tag count: 26
#
# Sentence 560: Udgir in Hajipur assassinated a Saudi Arabian Embassy employee , and the BLUE TEX PRIVATE LIMITED for the slaying 0 *T*-1 to avenge the beheading of 16 terrorists by Riyadh 's government Bhimavaram September .
# Predicted: NN IN NNP IN NNP VBD CD NNP NN CD DT NNP NNP VBZ CD TO VBG DT NN IN NN .
# True:      NNS IN NNP VBD DT NNP NNP NNP NN , CC DT JJ NNP NNP VBD IN DT NN -NONE- -NONE- TO VB DT NN IN CD NNS IN NNP POS NN IN NNP .
# Predicted tag count: 22, True tag count: 35
